# %% [markdown]
# ## IMPORT

# %%
import pandas as pd 
import numpy as np
from pytrends.request import TrendReq
from pytrends import dailydata
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: lxml in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (4.6.3)
# Requirement already satisfied: requests>=2.0 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (2.26.0)
# Requirement already satisfied: pandas>=0.25 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (1.20.3)
# Requirement already satisfied: six>=1.5 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/boom/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 각 자산별 DATA

# %%
Ndata = pd.read_csv("nas.csv")
Gdata = pd.read_csv("gold.csv")
Odata = pd.read_csv("oildpb.csv")
Bdata = pd.read_csv("bitcoin.csv")
Bndata = pd.read_csv("bnb.csv")
Rdata = pd.read_csv("xrp.csv")
Tdata = pd.read_csv("tron.csv")
Sdata = pd.read_csv("sbi.csv")
Ddata = pd.read_csv("doge.csv")
Edata = pd.read_csv("eth.csv")
Adata = pd.read_csv("ada.csv")
Sdata
# Out:
#             Date     Price      Open      High       Low       Vol. Change %
# 0    May 12 2021  0.000018  0.000030  0.000030  0.000018  86848.92B  -42.00%
# 1    May 13 2021  0.000021  0.000018  0.000021  0.000016  91382.21B   18.97%
# 2    May 14 2021  0.000018  0.000021  0.000021  0.000018  40929.23B  -12.14%
# 3    May 15 2021  0.000016  0.000018  0.000018  0.000015  43724.10B  -15.87%
# 4    May 16 2021  0.000018  0.000016  0.000018  0.000013  61614.36B   14.23%
# ..           ...       ...       ...       ...       ...        ...      ...
# 384  May 31 2022  0.000012  0.000012  0.000012  0.000012   5805.49B   -3.62%
# 385  Jun 01 2022  0.000011  0.000012  0.000012  0.000011   5923.04B   -7.16%
# 386  Jun 02 2022  0.000011  0.000011  0.000011  0.000011   3451.79B    2.94%
# 387  Jun 03 2022  0.000011  0.000011  0.000011  0.000011   3610.97B   -3.66%
# 388  Jun 04 2022  0.000011  0.000011  0.000011  0.000011   2537.39B   -0.46%
#
# [389 rows x 7 columns]

# %%
Bdata["거래량"] = Bdata["거래량"].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Edata["Vol."] = Edata["Vol."].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Rdata["거래량"] = Rdata["거래량"].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Bndata["거래량"] = Bndata["거래량"].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Tdata["거래량"] = Tdata["거래량"].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Ddata["Vol."] = Ddata["Vol."].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Adata["Vol."] = Adata["Vol."].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)
Sdata["Vol."] = Sdata["Vol."].replace({"K":"*1e3", "M":"*1e6", "B":"*1e9"}, regex=True).map(pd.eval).astype(int)

# %%
oil = Odata.set_index("DATE")
oil.columns = ['OIL']
oil.index = pd.to_datetime(oil.index)
oil = oil.sort_index()

# %%
bnb = pd.DataFrame(Bndata.iloc[:,[0,1,5]]).set_index("DATE")
bnb.columns = ['BNB', 'BNBV']
bnb.index = pd.to_datetime(bnb.index)
bnb = bnb.sort_index()
pbnb = bnb.pct_change().dropna()

# %%
xrp = pd.DataFrame(Rdata.iloc[:,[0,1,5]]).set_index("DATE")
xrp.columns = ["XRP", 'XRPV']
xrp.index = pd.to_datetime(xrp.index)
xrp = xrp.sort_index()
pxrp = xrp.pct_change().dropna()

# %%
btc = pd.DataFrame(Bdata.iloc[:,[0,1,5]]).set_index("DATE")
btc.columns = ["BTC", "BTCV"]
btc.index = pd.to_datetime(btc.index)
btc = btc.sort_index()
pbtc = btc.pct_change().dropna()

# %%
tron = pd.DataFrame(Tdata.iloc[:,[0,1,5]]).set_index("DATE")
tron.columns = ["TRON", "TRONV"]
tron.index = pd.to_datetime(tron.index)
tron = tron.sort_index()
ptron = tron.pct_change().dropna()

# %%
sbi = pd.DataFrame(Sdata.iloc[:,[0,1,5]]).set_index("Date")
sbi.columns = ["SHIB", "SHIBV"]
sbi.index = pd.to_datetime(sbi.index)
sbi = sbi.sort_index()
psbi = sbi.pct_change().dropna()

# %%
doge = pd.DataFrame(Ddata.iloc[:,[0,1,5]]).set_index("Date")
doge.columns = ["DOGE", "DOGEV"]
doge.index = pd.to_datetime(doge.index)
doge = doge.sort_index()
pdoge = doge.pct_change().dropna()

# %%
eth = pd.DataFrame(Edata.iloc[:,[0,1,5]]).set_index("Date")
eth.columns = ["ETH", "ETHV"]
eth.index = pd.to_datetime(eth.index)
eth = eth.sort_index()
peth = eth.pct_change().dropna()

# %%
ada = pd.DataFrame(Adata.iloc[:,[0,1,5]]).set_index("Date")
ada.columns = ["ADA","ADAV"]
ada.index = pd.to_datetime(ada.index)
ada = ada.sort_index()
pada = ada.pct_change().dropna()

# %%
gold = pd.DataFrame(Gdata.iloc[:,0:2]).set_index("DATE")
gold.columns = ["GOLD"]
gold.index = pd.to_datetime(gold.index)
gold = gold.sort_index()
pgold = gold.pct_change().dropna()

# %%
nas = pd.DataFrame(Ndata.iloc[:,0:2]).set_index("DATE")
nas.columns = ["NASDAQ"]
nas.index = pd.to_datetime(nas.index)
nas = nas.sort_index()
pnas = nas.pct_change().dropna()

# %%
idx = oil[oil["OILPRICE"] == "."].index
oil.drop(idx, inplace = True)
foil = oil.astype(float)
poil = foil.pct_change().dropna()

# %%
df = pd.concat([pnas, pgold, poil, pbtc, peth, pbnb, pxrp, pada, ptron, pdoge, psbi], join='outer', axis = 1)

# %% [markdown]
# ##

# %% [markdown]
# ## 비트코인과 나스닥의 상관관계
#  - t-value는 유의함을 보여주지만 상관관계는 0.41정도로 낮게 나타나기 때문에 공선성문제가 생기지 않을 것으로 판단하여 이후 OLS에서 둘 다 독립변수로 사용하였음

# %%
df_n = df.loc[:, ["BTC", "NASDAQ"]].dropna()
y_n = df_n.loc[:, ["BTC"]].dropna()
x_n = df_n.loc[:, ["NASDAQ"]].dropna()
x_n = sm.add_constant(x_n)
df.loc[:, ["BTC", "NASDAQ"]].corr()
# Out:
# /Users/boom/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#              BTC    NASDAQ
# BTC     1.000000  0.411842
# NASDAQ  0.411842  1.000000

# %%
nas_model = sm.OLS(y_n, x_n).fit().summary()
nas_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BTC   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     123.4
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           3.28e-26
# Time:                        22:24:10   Log-Likelihood:                 1085.1
# No. Observations:                 606   AIC:                            -2166.
# Df Residuals:                     604   BIC:                            -2157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.633      0.103      -0.001       0.006
# NASDAQ         0.9898      0.089     11.107      0.000       0.815       1.165
# ==============================================================================
# Omnibus:                       97.473   Durbin-Watson:                   2.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              906.935
# Skew:                          -0.364   Prob(JB):                    1.15e-197
# Kurtosis:                       8.949   Cond. No.                         54.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_v = df.loc[:, ['NASDAQ', 'GOLD', 'OILPRICE', 'BTC']]
df_v.corr()
# Out:
#             NASDAQ      GOLD  OILPRICE       BTC
# NASDAQ    1.000000  0.113950  0.102502  0.411842
# GOLD      0.113950  1.000000  0.030745  0.111988
# OILPRICE  0.102502  0.030745  1.000000  0.078313
# BTC       0.411842  0.111988  0.078313  1.000000

# %% [markdown]
# ## 각 코인별 데일리 트렌드 지수

# %%
daily_btc = pd.read_csv("daily_btc.csv")
daily_eth = pd.read_csv("daily_eth.csv")
daily_bnb = pd.read_csv("daily_bnb.csv")
daily_xrp = pd.read_csv("daily_xrp.csv")
daily_ada = pd.read_csv("daily_ada.csv")
daily_trn = pd.read_csv("daily_trn.csv")
daily_dog = pd.read_csv("daily_dog.csv")
daily_shb = pd.read_csv("daily_shb.csv")

# %%
dbtc = pd.DataFrame(daily_btc.iloc[:,1:3]).set_index("date")
dbtc.columns = ["daily_BTC"]
dbtc.index = pd.to_datetime(dbtc.index)
dbtc = dbtc.sort_index()

deth = pd.DataFrame(daily_eth.iloc[:,1:3]).set_index("date")
deth.columns = ["daily_ETH"]
deth.index = pd.to_datetime(deth.index)
deth = deth.sort_index()

dbnb = pd.DataFrame(daily_bnb.iloc[:,1:3]).set_index("date")
dbnb.columns = ["daily_BNB"]
dbnb.index = pd.to_datetime(dbnb.index)
dbnb = dbnb.sort_index()

dxrp = pd.DataFrame(daily_xrp.iloc[:,1:3]).set_index("date")
dxrp.columns = ["daily_XRP"]
dxrp.index = pd.to_datetime(dxrp.index)
dxrp = dxrp.sort_index()

dada = pd.DataFrame(daily_ada.iloc[:,1:3]).set_index("date")
dada.columns = ["daily_ADA"]
dada.index = pd.to_datetime(dada.index)
dada = dada.sort_index()

dtrn = pd.DataFrame(daily_trn.iloc[:,1:3]).set_index("date")
dtrn.columns = ["daily_TRON"]
dtrn.index = pd.to_datetime(dtrn.index)
dtrn = dtrn.sort_index()

ddog = pd.DataFrame(daily_dog.iloc[:,1:3]).set_index("date")
ddog.columns = ["daily_DOGE"]
ddog.index = pd.to_datetime(ddog.index)
ddog = ddog.sort_index()

dsbi = pd.DataFrame(daily_shb.iloc[:,1:3]).set_index("date")
dsbi.columns = ["daily_SHIB"]
dsbi.index = pd.to_datetime(dsbi.index)
dsbi = dsbi.sort_index()

# %% [markdown]
# ## 더미변수 만들기

# %%
df_eth = df.loc[:, ["ETH", "ETHV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_eth = pd.concat([df_eth, deth], join = 'inner', axis = 1).dropna()
df_bnb = df.loc[:, ["BNB", "BNBV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_bnb = pd.concat([df_bnb, dbnb], join = 'inner', axis = 1).dropna()
df_xrp = df.loc[:, ["XRP", "XRPV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_xrp = pd.concat([df_xrp, dxrp], join = 'inner', axis = 1).dropna()
df_ada = df.loc[:, ["ADA", "ADAV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_ada = pd.concat([df_ada, dada], join = 'inner', axis = 1).dropna()
df_trn = df.loc[:, ["TRON", "TRONV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_trn = pd.concat([df_trn, dtrn], join = 'inner', axis = 1).dropna()
df_dog = df.loc[:, ["DOGE", "DOGEV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_dog = pd.concat([df_dog, ddog], join = 'inner', axis = 1).dropna()
df_sbi = df.loc[:, ["SHIB", "SHIBV", "NASDAQ", "GOLD", "OILPRICE", "BTC"]].dropna()
df_sbi = pd.concat([df_sbi, dsbi], join = 'inner', axis = 1).dropna()

# %%
eth_d = df_eth["ETH"].apply(lambda x : True if x >= 0 else False)
eth_d = pd.get_dummies(pd.DataFrame(eth_d), columns = ["ETH"])
dd_eth = pd.concat([eth_d,deth], join='inner', axis=1).dropna()
dd_eth = dd_eth.loc[:,['ETH_False', 'ETH_True']].mul(dd_eth.loc[:,"daily_ETH"], axis = 0)

bnb_d = df_bnb["BNB"].apply(lambda x : True if x >= 0 else False)
bnb_d = pd.get_dummies(pd.DataFrame(bnb_d), columns = ["BNB"])
dd_bnb = pd.concat([bnb_d,dbnb], join='inner', axis=1).dropna()
dd_bnb = dd_bnb.loc[:,['BNB_False', 'BNB_True']].mul(dd_bnb.loc[:,"daily_BNB"], axis = 0)

xrp_d = df_xrp["XRP"].apply(lambda x : True if x >= 0 else False)
xrp_d = pd.get_dummies(pd.DataFrame(xrp_d), columns = ["XRP"])
dd_xrp = pd.concat([xrp_d,dxrp], join='inner', axis=1).dropna()
dd_xrp = dd_xrp.loc[:,['XRP_False', 'XRP_True']].mul(dd_xrp.loc[:,"daily_XRP"], axis = 0)

ada_d = df_ada["ADA"].apply(lambda x : True if x >= 0 else False)
ada_d = pd.get_dummies(pd.DataFrame(ada_d), columns = ["ADA"])
dd_ada = pd.concat([ada_d,dada], join='inner', axis=1).dropna()
dd_ada = dd_ada.loc[:,['ADA_False', 'ADA_True']].mul(dd_ada.loc[:,"daily_ADA"], axis = 0)

trn_d = df_trn["TRON"].apply(lambda x : True if x >= 0 else False)
trn_d = pd.get_dummies(pd.DataFrame(trn_d), columns = ["TRON"])
dd_trn = pd.concat([trn_d,dtrn], join='inner', axis=1).dropna()
dd_trn = dd_trn.loc[:,['TRON_False', 'TRON_True']].mul(dd_trn.loc[:,"daily_TRON"], axis = 0)

dog_d = df_dog["DOGE"].apply(lambda x : True if x >= 0 else False)
dog_d = pd.get_dummies(pd.DataFrame(dog_d), columns = ["DOGE"])
dd_dog = pd.concat([dog_d,ddog], join='inner', axis=1).dropna()
dd_dog = dd_dog.loc[:,['DOGE_False', 'DOGE_True']].mul(dd_dog.loc[:,"daily_DOGE"], axis = 0)

sbi_d = df_sbi["SHIB"].apply(lambda x : True if x >= 0 else False)
sbi_d = pd.get_dummies(pd.DataFrame(sbi_d), columns = ["SHIB"])
dd_sbi = pd.concat([sbi_d,dsbi], join='inner', axis=1).dropna()
dd_sbi = dd_sbi.loc[:,['SHIB_False', 'SHIB_True']].mul(dd_sbi.loc[:,"daily_SHIB"], axis = 0)

# %%
df_e = pd.concat([df_eth, dd_eth], join='inner', axis=1)
df_b = pd.concat([df_bnb, dd_bnb], join='inner', axis=1)
df_x = pd.concat([df_xrp, dd_xrp], join='inner', axis=1)
df_a = pd.concat([df_ada, dd_ada], join='inner', axis=1)
df_t = pd.concat([df_trn, dd_trn], join='inner', axis=1)
df_d = pd.concat([df_dog, dd_dog], join='inner', axis=1)
df_s = pd.concat([df_sbi, dd_sbi], join='inner', axis=1)

# %% [markdown]
# ## 각각 OLS에 대하여 독립변수, 종속변수 설정

# %%
y_e = df_e.loc[:, "ETH"].dropna()
x_e = df_e.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "ETHV", "ETH_False", "ETH_True"]].dropna()
#x_e = df_e.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_ETH"]].dropna()
x_e = sm.add_constant(x_e)

y_b = df_b.loc[:, "BNB"].dropna()
x_b = df_b.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "BNBV", "BNB_False", "BNB_True"]].dropna()
#x_b = df_b.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_BNB"]].dropna()
x_b = sm.add_constant(x_b)

y_x = df_x.loc[:, "XRP"].dropna()
x_x = df_x.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "XRPV", "XRP_False", "XRP_True"]].dropna()
#x_x = df_x.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_XRP"]].dropna()
x_x = sm.add_constant(x_x)

y_a = df_a.loc[:, "ADA"].dropna()
x_a = df_a.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "ADAV", "ADA_False", "ADA_True"]].dropna()
#x_a = df_a.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_ADA"]].dropna()
x_a = sm.add_constant(x_a)

y_t = df_t.loc[:, "TRON"].dropna()
x_t = df_t.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "TRONV", "TRON_False", "TRON_True"]].dropna()
#x_t = df_t.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_TRON"]].dropna()
x_t = sm.add_constant(x_t)

y_d = df_d.loc[:, "DOGE"].dropna()
x_d = df_d.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "DOGEV", "DOGE_False", "DOGE_True"]].dropna()
#x_d = df_d.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_DOGE"]].dropna()
x_d = sm.add_constant(x_d)

y_s = df_s.loc[:, "SHIB"].dropna()
x_s = df_s.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "SHIBV", "SHIB_False", "SHIB_True"]].dropna()
#x_s = df_s.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BTC", "daily_SHIB"]].dropna()
x_s = sm.add_constant(x_s)
# Out:
# /Users/boom/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# ## OLS 결과

# %%
eth_model = sm.OLS(y_e, x_e).fit().summary()
bnb_model = sm.OLS(y_b, x_b).fit().summary()
xrp_model = sm.OLS(y_x, x_x).fit().summary()
ada_model = sm.OLS(y_a, x_a).fit().summary()
trn_model = sm.OLS(y_t, x_t).fit().summary()
dog_model = sm.OLS(y_d, x_d).fit().summary()

# %%
eth_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ETH   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     295.5
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):          1.66e-188
# Time:                        22:52:47   Log-Likelihood:                 1331.2
# No. Observations:                 600   AIC:                            -2646.
# Df Residuals:                     592   BIC:                            -2611.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.004     -0.054      0.957      -0.009       0.008
# NASDAQ         0.2232      0.065      3.427      0.001       0.095       0.351
# GOLD           0.0675      0.095      0.709      0.479      -0.120       0.255
# OILPRICE       0.0013      0.008      0.173      0.863      -0.014       0.016
# BTC            0.7827      0.032     24.307      0.000       0.719       0.846
# ETHV        3.101e-06   9.28e-06      0.334      0.738   -1.51e-05    2.13e-05
# ETH_False     -0.0002    6.8e-05     -3.652      0.000      -0.000      -0.000
# ETH_True       0.0003   6.47e-05      4.120      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       81.636   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              682.730
# Skew:                           0.239   Prob(JB):                    5.59e-149
# Kurtosis:                       8.204   Cond. No.                     1.04e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
bnb_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BNB   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     96.25
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           1.98e-93
# Time:                        22:52:47   Log-Likelihood:                 983.76
# No. Observations:                 600   AIC:                            -1952.
# Df Residuals:                     592   BIC:                            -1916.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.012      0.169      0.866      -0.021       0.025
# NASDAQ         0.1934      0.116      1.663      0.097      -0.035       0.422
# GOLD           0.0508      0.170      0.299      0.765      -0.283       0.385
# OILPRICE       0.0063      0.014      0.463      0.644      -0.020       0.033
# BTC            0.7161      0.056     12.694      0.000       0.605       0.827
# BNBV        2.579e-05      0.000      0.245      0.806      -0.000       0.000
# BNB_False     -0.0003      0.000     -1.881      0.060      -0.001    1.19e-05
# BNB_True       0.0003      0.000      2.032      0.043    9.69e-06       0.001
# ==============================================================================
# Omnibus:                      638.126   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            70153.516
# Skew:                           4.598   Prob(JB):                         0.00
# Kurtosis:                      55.169   Cond. No.                     5.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
xrp_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    XRP   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     90.16
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           4.62e-89
# Time:                        22:52:47   Log-Likelihood:                 960.25
# No. Observations:                 600   AIC:                            -1905.
# Df Residuals:                     592   BIC:                            -1869.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0061      0.006      1.064      0.288      -0.005       0.017
# NASDAQ         0.0999      0.121      0.826      0.409      -0.138       0.338
# GOLD          -0.1659      0.176     -0.942      0.347      -0.512       0.180
# OILPRICE      -0.0067      0.014     -0.473      0.636      -0.034       0.021
# BTC            0.7073      0.057     12.339      0.000       0.595       0.820
# XRPV           0.0157      0.004      3.987      0.000       0.008       0.023
# XRP_False     -0.0006      0.000     -5.573      0.000      -0.001      -0.000
# XRP_True       0.0003   9.64e-05      2.763      0.006    7.71e-05       0.000
# ==============================================================================
# Omnibus:                      207.947   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8158.224
# Skew:                           0.796   Prob(JB):                         0.00
# Kurtosis:                      20.994   Cond. No.                     4.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ada_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ADA   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.633
# Method:                 Least Squares   F-statistic:                     148.9
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):          4.43e-126
# Time:                        22:52:47   Log-Likelihood:                 1069.6
# No. Observations:                 600   AIC:                            -2123.
# Df Residuals:                     592   BIC:                            -2088.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0237      0.014      1.703      0.089      -0.004       0.051
# NASDAQ         0.2573      0.101      2.543      0.011       0.059       0.456
# GOLD          -0.0985      0.147     -0.671      0.502      -0.387       0.190
# OILPRICE       0.0004      0.012      0.037      0.971      -0.023       0.024
# BTC            0.6530      0.047     13.941      0.000       0.561       0.745
# ADAV           0.0052      0.002      2.950      0.003       0.002       0.009
# ADA_False     -0.0006      0.000     -3.815      0.000      -0.001      -0.000
# ADA_True    8.279e-05      0.000      0.509      0.611      -0.000       0.000
# ==============================================================================
# Omnibus:                      234.122   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2239.239
# Skew:                           1.451   Prob(JB):                         0.00
# Kurtosis:                      12.008   Cond. No.                     5.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
trn_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   TRON   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     132.0
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):          1.89e-116
# Time:                        22:52:47   Log-Likelihood:                 1090.9
# No. Observations:                 600   AIC:                            -2166.
# Df Residuals:                     592   BIC:                            -2131.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0157      0.009     -1.686      0.092      -0.034       0.003
# NASDAQ         0.0440      0.097      0.452      0.652      -0.147       0.235
# GOLD           0.0582      0.142      0.410      0.682      -0.221       0.337
# OILPRICE      -0.0011      0.011     -0.096      0.924      -0.023       0.021
# BTC            0.6712      0.046     14.638      0.000       0.581       0.761
# TRONV          0.0116      0.003      4.194      0.000       0.006       0.017
# TRON_False    -0.0002      0.000     -1.160      0.246      -0.000       0.000
# TRON_True      0.0006      0.000      4.335      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                      189.362   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2880.571
# Skew:                           0.959   Prob(JB):                         0.00
# Kurtosis:                      13.561   Cond. No.                     4.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dog_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   DOGE   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6410
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):              0.722
# Time:                        22:52:47   Log-Likelihood:                -1406.5
# No. Observations:                 600   AIC:                             2829.
# Df Residuals:                     592   BIC:                             2864.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1108      0.264     -0.419      0.675      -0.630       0.408
# NASDAQ        -0.1220      6.239     -0.020      0.984     -12.376      12.132
# GOLD           3.3199      9.129      0.364      0.716     -14.608      21.248
# OILPRICE      -0.0689      0.733     -0.094      0.925      -1.508       1.370
# BTC           -1.3101      2.859     -0.458      0.647      -6.925       4.304
# DOGEV         -0.0025      0.064     -0.039      0.969      -0.129       0.124
# DOGE_False     0.0006      0.005      0.137      0.891      -0.009       0.010
# DOGE_True      0.0071      0.004      1.600      0.110      -0.002       0.016
# ==============================================================================
# Omnibus:                     1507.731   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8518950.963
# Skew:                          24.032   Prob(JB):                         0.00
# Kurtosis:                     584.763   Cond. No.                     4.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 2022~

# %% [markdown]
# #### NASDAQ vs BTC

# %%
df_n2 = df.loc['2022-01-01':, ["BTC", "NASDAQ"]].dropna()
y_n2 = df_n2.loc[:, ["BTC"]].dropna()
x_n2 = df_n2.loc[:, ["NASDAQ"]].dropna()
x_n2 = sm.add_constant(x_n2)
df_n2.loc[:, ["BTC", "NASDAQ"]].corr()
# Out:
# /Users/boom/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#              BTC    NASDAQ
# BTC     1.000000  0.563674
# NASDAQ  0.563674  1.000000

# %%
df_v2 = df.loc['2022-01-01':, ['NASDAQ', 'GOLD', 'OILPRICE', 'BTC']]
df_v2.corr()
# Out:
#             NASDAQ      GOLD  OILPRICE       BTC
# NASDAQ    1.000000 -0.217113 -0.061262  0.563674
# GOLD     -0.217113  1.000000  0.463942 -0.098298
# OILPRICE -0.061262  0.463942  1.000000  0.071313
# BTC       0.563674 -0.098298  0.071313  1.000000

# %%
nas_model2 = sm.OLS(y_n2, x_n2).fit().summary()
nas_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BTC   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     46.57
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           6.90e-10
# Time:                        22:24:11   Log-Likelihood:                 205.55
# No. Observations:                 102   AIC:                            -407.1
# Df Residuals:                     100   BIC:                            -401.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.003     -0.304      0.762      -0.007       0.005
# NASDAQ         1.0291      0.151      6.824      0.000       0.730       1.328
# ==============================================================================
# Omnibus:                       26.461   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.422
# Skew:                           0.930   Prob(JB):                     1.69e-14
# Kurtosis:                       6.386   Cond. No.                         46.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### ALT vs BTC

# %%
df_e2 = df_e.loc['2022-01-01':]
df_b2 = df_b.loc['2022-01-01':]
df_x2 = df_x.loc['2022-01-01':]
df_a2 = df_a.loc['2022-01-01':]
df_t2 = df_t.loc['2022-01-01':]
df_d2 = df_d.loc['2022-01-01':]
df_s2 = df_s.loc['2022-01-01':]

# %%
y_e2 = df_e2.loc[:, "ETH"].dropna()
x_e2 = df_e2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "ETHV", "BTC", "ETH_False", "ETH_True"]].dropna()
x_e2 = sm.add_constant(x_e2)

y_b2 = df_b2.loc[:, "BNB"].dropna()
x_b2 = df_b2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "BNBV", "BTC", "BNB_False", "BNB_True"]].dropna()
x_b2 = sm.add_constant(x_b2)

y_x2 = df_x2.loc[:, "XRP"].dropna()
x_x2 = df_x2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "XRPV", "BTC", "XRP_False", "XRP_True"]].dropna()
x_x2 = sm.add_constant(x_x2)

y_a2 = df_a2.loc[:, "ADA"].dropna()
x_a2 = df_a2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "ADAV", "BTC", "ADA_False", "ADA_True"]].dropna()
x_a2 = sm.add_constant(x_a2)

y_t2 = df_t2.loc[:, "TRON"].dropna()
x_t2 = df_t2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "TRONV", "BTC", "TRON_False", "TRON_True"]].dropna()
x_t2 = sm.add_constant(x_t2)

y_d2 = df_d2.loc[:, "DOGE"].dropna()
x_d2 = df_d2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "DOGEV", "BTC", "DOGE_False", "DOGE_True"]].dropna()
x_d2 = sm.add_constant(x_d2)

y_s2 = df_s2.loc[:, "SHIB"].dropna()
x_s2 = df_s2.loc[:, ["NASDAQ", "GOLD", "OILPRICE", "SHIBV", "BTC", "SHIB_False", "SHIB_True"]].dropna()
x_s2 = sm.add_constant(x_s2)

eth_model2 = sm.OLS(y_e2, x_e2).fit().summary()
bnb_model2 = sm.OLS(y_b2, x_b2).fit().summary()
xrp_model2 = sm.OLS(y_x2, x_x2).fit().summary()
ada_model2 = sm.OLS(y_a2, x_a2).fit().summary()
trn_model2 = sm.OLS(y_t2, x_t2).fit().summary()
dog_model2 = sm.OLS(y_d2, x_d2).fit().summary()
sbi_model2 = sm.OLS(y_s2, x_s2).fit().summary()
# Out:
# /Users/boom/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
eth_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ETH   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     112.4
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           1.13e-41
# Time:                        22:58:21   Log-Likelihood:                 273.87
# No. Observations:                  98   AIC:                            -531.7
# Df Residuals:                      90   BIC:                            -511.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0095      0.008      1.244      0.217      -0.006       0.025
# NASDAQ         0.3062      0.099      3.096      0.003       0.110       0.503
# GOLD           0.0921      0.179      0.516      0.607      -0.263       0.447
# OILPRICE       0.0150      0.052      0.288      0.774      -0.088       0.118
# ETHV        9.812e-07   5.69e-06      0.172      0.864   -1.03e-05    1.23e-05
# BTC            0.7719      0.059     13.128      0.000       0.655       0.889
# ETH_False     -0.0003      0.000     -2.791      0.006      -0.001   -8.44e-05
# ETH_True    1.513e-05      0.000      0.143      0.886      -0.000       0.000
# ==============================================================================
# Omnibus:                        6.227   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                6.338
# Skew:                          -0.404   Prob(JB):                       0.0420
# Kurtosis:                       3.948   Cond. No.                     3.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
bnb_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BNB   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     46.38
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           3.47e-27
# Time:                        22:58:21   Log-Likelihood:                 238.70
# No. Observations:                  98   AIC:                            -461.4
# Df Residuals:                      90   BIC:                            -440.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0057      0.029      0.196      0.845      -0.052       0.064
# NASDAQ         0.1519      0.137      1.105      0.272      -0.121       0.425
# GOLD           0.0046      0.255      0.018      0.986      -0.502       0.511
# OILPRICE       0.0939      0.075      1.253      0.214      -0.055       0.243
# BNBV       -2.091e-05   5.17e-05     -0.404      0.687      -0.000    8.19e-05
# BTC            0.6461      0.090      7.152      0.000       0.467       0.826
# BNB_False     -0.0002      0.000     -0.710      0.480      -0.001       0.000
# BNB_True       0.0001      0.000      0.351      0.726      -0.001       0.001
# ==============================================================================
# Omnibus:                       29.518   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.516
# Skew:                          -1.001   Prob(JB):                     7.33e-19
# Kurtosis:                       7.055   Cond. No.                     7.41e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
xrp_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    XRP   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     27.61
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           6.91e-20
# Time:                        22:58:21   Log-Likelihood:                 205.82
# No. Observations:                  98   AIC:                            -395.6
# Df Residuals:                      90   BIC:                            -375.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.015     -0.334      0.739      -0.035       0.025
# NASDAQ         0.2123      0.190      1.115      0.268      -0.166       0.591
# GOLD           0.0022      0.359      0.006      0.995      -0.710       0.715
# OILPRICE      -0.0055      0.108     -0.051      0.959      -0.219       0.208
# XRPV           0.0092      0.006      1.473      0.144      -0.003       0.022
# BTC            0.6511      0.111      5.843      0.000       0.430       0.872
# XRP_False     -0.0003      0.000     -1.198      0.234      -0.001       0.000
# XRP_True       0.0003      0.000      1.472      0.144      -0.000       0.001
# ==============================================================================
# Omnibus:                       37.143   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.622
# Skew:                           0.890   Prob(JB):                     1.27e-58
# Kurtosis:                      10.882   Cond. No.                     5.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ada_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ADA   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     42.96
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           4.83e-26
# Time:                        22:58:21   Log-Likelihood:                 207.90
# No. Observations:                  98   AIC:                            -399.8
# Df Residuals:                      90   BIC:                            -379.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0300      0.055      0.543      0.588      -0.080       0.140
# NASDAQ         0.3517      0.194      1.813      0.073      -0.034       0.737
# GOLD           0.0575      0.350      0.164      0.870      -0.638       0.753
# OILPRICE       0.1853      0.102      1.819      0.072      -0.017       0.388
# ADAV          -0.0030      0.005     -0.548      0.585      -0.014       0.008
# BTC            0.6969      0.113      6.193      0.000       0.473       0.920
# ADA_False     -0.0006      0.001     -1.027      0.307      -0.002       0.001
# ADA_True   -9.226e-05      0.001     -0.154      0.878      -0.001       0.001
# ==============================================================================
# Omnibus:                       13.486   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               34.956
# Skew:                           0.345   Prob(JB):                     2.57e-08
# Kurtosis:                       5.843   Cond. No.                     7.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
trn_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   TRON   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     21.41
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           9.94e-17
# Time:                        22:58:21   Log-Likelihood:                 201.33
# No. Observations:                  98   AIC:                            -386.7
# Df Residuals:                      90   BIC:                            -366.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0154      0.033      0.468      0.641      -0.050       0.081
# NASDAQ         0.2922      0.204      1.430      0.156      -0.114       0.698
# GOLD           0.1402      0.380      0.369      0.713      -0.615       0.895
# OILPRICE       0.2462      0.108      2.285      0.025       0.032       0.460
# TRONV          0.0238      0.006      3.695      0.000       0.011       0.037
# BTC            0.3616      0.120      3.010      0.003       0.123       0.600
# TRON_False    -0.0006      0.000     -1.260      0.211      -0.001       0.000
# TRON_True   6.412e-05      0.000      0.143      0.886      -0.001       0.001
# ==============================================================================
# Omnibus:                       36.720   Durbin-Watson:                   2.621
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.262
# Skew:                           1.198   Prob(JB):                     6.31e-28
# Kurtosis:                       7.993   Cond. No.                     6.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dog_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   DOGE   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     25.52
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           7.08e-19
# Time:                        22:58:21   Log-Likelihood:                 193.87
# No. Observations:                  98   AIC:                            -371.7
# Df Residuals:                      90   BIC:                            -351.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0112      0.014     -0.778      0.439      -0.040       0.017
# NASDAQ         0.2714      0.215      1.262      0.210      -0.156       0.699
# GOLD          -0.0862      0.406     -0.212      0.832      -0.893       0.721
# OILPRICE       0.1022      0.116      0.879      0.382      -0.129       0.333
# DOGEV          0.0096      0.003      3.748      0.000       0.004       0.015
# BTC            0.5222      0.133      3.927      0.000       0.258       0.786
# DOGE_False    -0.0002      0.000     -1.204      0.232      -0.001       0.000
# DOGE_True      0.0004      0.000      1.931      0.057    -1.2e-05       0.001
# ==============================================================================
# Omnibus:                       34.404   Durbin-Watson:                   2.618
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              222.505
# Skew:                          -0.830   Prob(JB):                     4.83e-49
# Kurtosis:                      10.193   Cond. No.                     6.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sbi_model2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   SHIB   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     34.16
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):           9.44e-23
# Time:                        22:58:21   Log-Likelihood:                 186.88
# No. Observations:                  98   AIC:                            -357.8
# Df Residuals:                      90   BIC:                            -337.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0130      0.009     -1.403      0.164      -0.031       0.005
# NASDAQ         0.2330      0.234      0.997      0.322      -0.231       0.697
# GOLD           0.3095      0.434      0.713      0.478      -0.553       1.172
# OILPRICE       0.1287      0.126      1.022      0.309      -0.121       0.379
# SHIBV          0.0022      0.005      0.401      0.690      -0.009       0.013
# BTC            0.6492      0.140      4.635      0.000       0.371       0.927
# SHIB_False    -0.0004      0.000     -2.233      0.028      -0.001   -4.96e-05
# SHIB_True      0.0009      0.000      4.582      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       20.299   Durbin-Watson:                   2.547
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.831
# Skew:                          -0.546   Prob(JB):                     1.13e-15
# Kurtosis:                       6.958   Cond. No.                     4.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
